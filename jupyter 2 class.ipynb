# %%
x = 1
x = x + 3
print(x)

vowels = ['a', 'o', 'u']
vowels = vowels + ['e', 'i']
print(vowels)
# Out:
# 4
# ['a', 'o', 'u', 'e', 'i']

# %%
vowels.append('æ')
print(vowels)
# Out:
# ['a', 'o', 'u', 'e', 'i', 'æ']

# %%
print(vowels[0])
# Out:
# a

# %%
sentence = "the cat is on the mat"
words = set(sentence.split())  # превращаем список, который возвращает split(), в массив
animals = set(['cat', 'dog', 'elephant', 'crocodile', 'fox', 'cat', 'elephant'])

print(words)
print(animals)
# Out:
# {'on', 'the', 'mat', 'is', 'cat'}
# {'dog', 'fox', 'crocodile', 'elephant', 'cat'}

# %%
animals.add('tiger')
print(animals)
# Out:
# {'tiger', 'dog', 'fox', 'crocodile', 'elephant', 'cat'}

# %%
x=""" живут на земле
 существа неземной красоты.
 я думаю, ты догадался,
 что это - коты.
 (да, кошки - хорошее слово, 
 научное слово, но ты,
 читатель, забудь это слово
 и помни лишь слово коты!)
 коты грациозны -
 какая гимнастка
 сравнится с котом?
 взгляни, например,
 как он лижет себя под хвостом!
 коты музыкальны -
 не верь, о читатель,
 пустым разговорам,
 что будто кошачий концерт
 не сравнится с ангельским хором...
 а впрочем, коты
 не боятся людской клеветы.
 коты - они выше мирской суеты.
 поверь, словно светоч среди темноты,
 нам посланы свыше коты!..
 но тот, кто не хочет
 (а ты ведь не хочешь?)
 с котами расстаться,
 тот должен серьёзно
 (да, очень серьёзно!)
 с котами считаться.
 наука открыла:
 природа не можеть терпеть пустоты.
 добавлю: особенно -
 лучшая часть этой самой природы -
 коты.
 держать на голодном пайке?
 говорят,
 можно так обращаться с людьми...
 но если ты держишь котов,
 то корми, и корми, и корми!
 коты в нашем доме
 покой и уют создают, -
 но сами коты
 тоже любят покой и уют!
 и если, допустим,
 внезапно захочешь
 ударить в тамтам,
 сначала подумай,
 приятно ли это котам!
 а главное - даже не пробуй
 к котам обращаться "на ты",
 поскольку любой,
 самый маленький кот -
 это тоже коты!
 советую не забывать,
 что коты -
 несомненные родичи тигров,
 и помнить народную мудрость
 (её я вынес в эпиграф).
 осталось добавить,
 что тех, кто не хочет
 серьёзно считаться с котами,
 коты (и вполне справедливо!)
 считают скотами!"""
print(x)
# Out:
#  живут на земле
#  существа неземной красоты.
#  я думаю, ты догадался,
#  что это - коты.
#  (да, кошки - хорошее слово,
#  научное слово, но ты,
#  читатель, забудь это слово
#  и помни лишь слово коты!)
#  коты грациозны -
#  какая гимнастка
#  сравнится с котом?
#  взгляни, например,
#  как он лижет себя под хвостом!
#  коты музыкальны -
#  не верь, о читатель,
#  пустым разговорам,
#  что будто кошачий концерт
#  не сравнится с ангельским хором...
#  а впрочем, коты
#  не боятся людской клеветы.
#  коты - они выше мирской суеты.
#  поверь, словно светоч среди темноты,
#  нам посланы свыше коты!..
#  но тот, кто не хочет
#  (а ты ведь не хочешь?)
#  с котами расстаться,
#  тот должен серьёзно
#  (да, очень серьёзно!)
#  с котами считаться.
#  наука открыла:
#  природа не можеть терпеть пустоты.
#  добавлю: особенно -
#  лучшая часть этой самой природы -
#  коты.
#  держать на голодном пайке?
#  говорят,
#  можно так обращаться с людьми...
#  но если ты держишь котов,
#  то корми, и корми, и корми!
#  коты в нашем доме
#  покой и уют создают, -
#  но сами коты
#  тоже любят покой и уют!
#  и если, допустим,
#  внезапно захочешь
#  ударить в тамтам,
#  сначала подумай,
#  приятно ли это котам!
#  а главное - даже не пробуй
#  к котам обращаться "на ты",
#  поскольку любой,
#  самый маленький кот -
#  это тоже коты!
#  советую не забывать,
#  что коты -
#  несомненные родичи тигров,
#  и помнить народную мудрость
#  (её я вынес в эпиграф).
#  осталось добавить,
#  что тех, кто не хочет
#  серьёзно считаться с котами,
#  коты (и вполне справедливо!)
#  считают скотами!

# %%
#2.Нужно записать стихотворение в переменную
text=""" живут на земле
 существа неземной красоты.
 я думаю, ты догадался,
 что это - коты.
 (да, кошки - хорошее слово, 
 научное слово, но ты,
 читатель, забудь это слово
 и помни лишь слово коты!)
 коты грациозны -
 какая гимнастка
 сравнится с котом?
 взгляни, например,
 как он лижет себя под хвостом!
 коты музыкальны -
 не верь, о читатель,
 пустым разговорам,
 что будто кошачий концерт
 не сравнится с ангельским хором...
 а впрочем, коты
 не боятся людской клеветы.
 коты - они выше мирской суеты.
 поверь, словно светоч среди темноты,
 нам посланы свыше коты!..
 но тот, кто не хочет
 (а ты ведь не хочешь?)
 с котами расстаться,
 тот должен серьёзно
 (да, очень серьёзно!)
 с котами считаться.
 наука открыла:
 природа не можеть терпеть пустоты.
 добавлю: особенно -
 лучшая часть этой самой природы -
 коты.
 держать на голодном пайке?
 говорят,
 можно так обращаться с людьми...
 но если ты держишь котов,
 то корми, и корми, и корми!
 коты в нашем доме
 покой и уют создают, -
 но сами коты
 тоже любят покой и уют!
 и если, допустим,
 внезапно захочешь
 ударить в тамтам,
 сначала подумай,
 приятно ли это котам!
 а главное - даже не пробуй
 к котам обращаться "на ты",
 поскольку любой,
 самый маленький кот -
 это тоже коты!
 советую не забывать,
 что коты -
 несомненные родичи тигров,
 и помнить народную мудрость
 (её я вынес в эпиграф).
 осталось добавить,
 что тех, кто не хочет
 серьёзно считаться с котами,
 коты (и вполне справедливо!)
 считают скотами!"""

# %%
print(text)
# Out:
#  живут на земле
#  существа неземной красоты.
#  я думаю, ты догадался,
#  что это - коты.
#  (да, кошки - хорошее слово,
#  научное слово, но ты,
#  читатель, забудь это слово
#  и помни лишь слово коты!)
#  коты грациозны -
#  какая гимнастка
#  сравнится с котом?
#  взгляни, например,
#  как он лижет себя под хвостом!
#  коты музыкальны -
#  не верь, о читатель,
#  пустым разговорам,
#  что будто кошачий концерт
#  не сравнится с ангельским хором...
#  а впрочем, коты
#  не боятся людской клеветы.
#  коты - они выше мирской суеты.
#  поверь, словно светоч среди темноты,
#  нам посланы свыше коты!..
#  но тот, кто не хочет
#  (а ты ведь не хочешь?)
#  с котами расстаться,
#  тот должен серьёзно
#  (да, очень серьёзно!)
#  с котами считаться.
#  наука открыла:
#  природа не можеть терпеть пустоты.
#  добавлю: особенно -
#  лучшая часть этой самой природы -
#  коты.
#  держать на голодном пайке?
#  говорят,
#  можно так обращаться с людьми...
#  но если ты держишь котов,
#  то корми, и корми, и корми!
#  коты в нашем доме
#  покой и уют создают, -
#  но сами коты
#  тоже любят покой и уют!
#  и если, допустим,
#  внезапно захочешь
#  ударить в тамтам,
#  сначала подумай,
#  приятно ли это котам!
#  а главное - даже не пробуй
#  к котам обращаться "на ты",
#  поскольку любой,
#  самый маленький кот -
#  это тоже коты!
#  советую не забывать,
#  что коты -
#  несомненные родичи тигров,
#  и помнить народную мудрость
#  (её я вынес в эпиграф).
#  осталось добавить,
#  что тех, кто не хочет
#  серьёзно считаться с котами,
#  коты (и вполне справедливо!)
#  считают скотами!

# %%
# Затем разбить его на массив слов по пробелам
words = text.split()
с
print(words)
# Out:
# ['живут', 'на', 'земле', 'существа', 'неземной', 'красоты.', 'я', 'думаю,', 'ты', 'догадался,', 'что', 'это', '-', 'коты.', '(да,', 'кошки', '-', 'хорошее', 'слово,', 'научное', 'слово,', 'но', 'ты,', 'читатель,', 'забудь', 'это', 'слово', 'и', 'помни', 'лишь', 'слово', 'коты!)', 'коты', 'грациозны', '-', 'какая', 'гимнастка', 'сравнится', 'с', 'котом?', 'взгляни,', 'например,', 'как', 'он', 'лижет', 'себя', 'под', 'хвостом!', 'коты', 'музыкальны', '-', 'не', 'верь,', 'о', 'читатель,', 'пустым', 'разговорам,', 'что', 'будто', 'кошачий', 'концерт', 'не', 'сравнится', 'с', 'ангельским', 'хором...', 'а', 'впрочем,', 'коты', 'не', 'боятся', 'людской', 'клеветы.', 'коты', '-', 'они', 'выше', 'мирской', 'суеты.', 'поверь,', 'словно', 'светоч', 'среди', 'темноты,', 'нам', 'посланы', 'свыше', 'коты!..', 'но', 'тот,', 'кто', 'не', 'хочет', '(а', 'ты', 'ведь', 'не', 'хочешь?)', 'с', 'котами', 'расстаться,', 'тот', 'должен', 'серьёзно', '(да,', 'очень', 'серьёзно!)', 'с', 'котами', 'считаться.', 'наука', 'открыла:', 'природа', 'не', 'можеть', 'терпеть', 'пустоты.', 'добавлю:', 'особенно', '-', 'лучшая', 'часть', 'этой', 'самой', 'природы', '-', 'коты.', 'держать', 'на', 'голодном', 'пайке?', 'говорят,', 'можно', 'так', 'обращаться', 'с', 'людьми...', 'но', 'если', 'ты', 'держишь', 'котов,', 'то', 'корми,', 'и', 'корми,', 'и', 'корми!', 'коты', 'в', 'нашем', 'доме', 'покой', 'и', 'уют', 'создают,', '-', 'но', 'сами', 'коты', 'тоже', 'любят', 'покой', 'и', 'уют!', 'и', 'если,', 'допустим,', 'внезапно', 'захочешь', 'ударить', 'в', 'тамтам,', 'сначала', 'подумай,', 'приятно', 'ли', 'это', 'котам!', 'а', 'главное', '-', 'даже', 'не', 'пробуй', 'к', 'котам', 'обращаться', '"на', 'ты",', 'поскольку', 'любой,', 'самый', 'маленький', 'кот', '-', 'это', 'тоже', 'коты!', 'советую', 'не', 'забывать,', 'что', 'коты', '-', 'несомненные', 'родичи', 'тигров,', 'и', 'помнить', 'народную', 'мудрость', '(её', 'я', 'вынес', 'в', 'эпиграф).', 'осталось', 'добавить,', 'что', 'тех,', 'кто', 'не', 'хочет', 'серьёзно', 'считаться', 'с', 'котами,', 'коты', '(и', 'вполне', 'справедливо!)', 'считают', 'скотами!']

# %%
# Распечатать количество уникальных слов
unique = set(text.split()) 
print(unique)
# Out:
# {'но', 'мирской', 'обращаться', 'с', '-', 'тамтам,', 'ведь', 'тигров,', 'помни', 'наука', 'к', 'нам', 'котам!', 'сами', 'котам', 'слово,', 'пробуй', 'уют!', 'лижет', 'суеты.', 'словно', 'земле', 'то', 'даже', 'среди', 'впрочем,', 'котами,', 'существа', 'читатель,', 'себя', 'допустим,', 'боятся', 'что', 'несомненные', 'осталось', 'серьёзно', 'и', 'выше', 'это', 'голодном', 'подумай,', 'о', 'они', 'тот,', 'тот', 'любят', '(и', 'посланы', 'говорят,', 'как', 'ты', 'очень', 'советую', 'держать', 'корми!', 'кошки', 'коты', 'грациозны', 'мудрость', '(её', 'в', 'терпеть', 'этой', 'на', 'коты!', 'справедливо!)', '(да,', 'пустым', 'хочешь?)', 'расстаться,', 'пустоты.', 'живут', 'музыкальны', 'если,', 'под', 'ли', 'так', 'считаться.', 'нашем', 'помнить', 'я', 'думаю,', 'верь,', 'слово', 'часть', 'родичи', 'внезапно', 'покой', 'корми,', 'держишь', 'тоже', 'маленький', 'светоч', 'какая', 'вполне', 'народную', 'красоты.', 'считают', 'котами', 'особенно', 'гимнастка', 'ты",', 'научное', 'эпиграф).', 'уют', 'скотами!', 'добавить,', 'кто', 'сначала', 'свыше', 'людьми...', 'ты,', 'ударить', 'концерт', 'поверь,', 'приятно', 'серьёзно!)', 'тех,', 'самый', 'кот', 'поскольку', 'если', 'забывать,', 'природа', 'можно', 'например,', 'хорошее', 'хором...', 'лишь', 'клеветы.', '"на', 'любой,', 'будто', 'открыла:', 'котов,', 'создают,', 'природы', 'ангельским', 'котом?', 'кошачий', 'считаться', 'доме', 'лучшая', 'людской', 'главное', 'хвостом!', 'вынес', 'самой', 'темноты,', 'пайке?', 'сравнится', 'добавлю:', 'захочешь', 'догадался,', 'забудь', 'разговорам,', 'коты!..', 'хочет', '(а', 'а', 'коты.', 'не', 'он', 'неземной', 'можеть', 'коты!)', 'должен', 'взгляни,'}

# %%
# Распечатать общее количество слов
print(len(words))
# Out:
# 234

# %%
# Распечатать количество уникальных слов
print(len(unique))
# Out:
# 168

# %%
# Посчитать количество вхождений слова "коты"
words = tuple(words)
print((words).count(коты))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6ab1128bdf86> in <module>()
#       1 # Посчитать количество вхождений слова "коты"
#       2 words = tuple(words)
# ----> 3 print((words).count(коты))
#
# NameError: name 'коты' is not defined

# %%
print(len(words))
# Out:
# 234

# %%
print((words).count("коты"))
# Out:
# 8

# %%
print((words).count("\n"))
# Out:
# 0

# %%
print((text).count("\n"))
# Out:
# 62

# %%
# punctuation - это просто строка со знаками препинания
from string import punctuation
print(punctuation)

sentence = text

words = text.split()
words = [w.strip(punctuation) for w in words]
print(words)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# ['живут', 'на', 'земле', 'существа', 'неземной', 'красоты', 'я', 'думаю', 'ты', 'догадался', 'что', 'это', '', 'коты', 'да', 'кошки', '', 'хорошее', 'слово', 'научное', 'слово', 'но', 'ты', 'читатель', 'забудь', 'это', 'слово', 'и', 'помни', 'лишь', 'слово', 'коты', 'коты', 'грациозны', '', 'какая', 'гимнастка', 'сравнится', 'с', 'котом', 'взгляни', 'например', 'как', 'он', 'лижет', 'себя', 'под', 'хвостом', 'коты', 'музыкальны', '', 'не', 'верь', 'о', 'читатель', 'пустым', 'разговорам', 'что', 'будто', 'кошачий', 'концерт', 'не', 'сравнится', 'с', 'ангельским', 'хором', 'а', 'впрочем', 'коты', 'не', 'боятся', 'людской', 'клеветы', 'коты', '', 'они', 'выше', 'мирской', 'суеты', 'поверь', 'словно', 'светоч', 'среди', 'темноты', 'нам', 'посланы', 'свыше', 'коты', 'но', 'тот', 'кто', 'не', 'хочет', 'а', 'ты', 'ведь', 'не', 'хочешь', 'с', 'котами', 'расстаться', 'тот', 'должен', 'серьёзно', 'да', 'очень', 'серьёзно', 'с', 'котами', 'считаться', 'наука', 'открыла', 'природа', 'не', 'можеть', 'терпеть', 'пустоты', 'добавлю', 'особенно', '', 'лучшая', 'часть', 'этой', 'самой', 'природы', '', 'коты', 'держать', 'на', 'голодном', 'пайке', 'говорят', 'можно', 'так', 'обращаться', 'с', 'людьми', 'но', 'если', 'ты', 'держишь', 'котов', 'то', 'корми', 'и', 'корми', 'и', 'корми', 'коты', 'в', 'нашем', 'доме', 'покой', 'и', 'уют', 'создают', '', 'но', 'сами', 'коты', 'тоже', 'любят', 'покой', 'и', 'уют', 'и', 'если', 'допустим', 'внезапно', 'захочешь', 'ударить', 'в', 'тамтам', 'сначала', 'подумай', 'приятно', 'ли', 'это', 'котам', 'а', 'главное', '', 'даже', 'не', 'пробуй', 'к', 'котам', 'обращаться', 'на', 'ты', 'поскольку', 'любой', 'самый', 'маленький', 'кот', '', 'это', 'тоже', 'коты', 'советую', 'не', 'забывать', 'что', 'коты', '', 'несомненные', 'родичи', 'тигров', 'и', 'помнить', 'народную', 'мудрость', 'её', 'я', 'вынес', 'в', 'эпиграф', 'осталось', 'добавить', 'что', 'тех', 'кто', 'не', 'хочет', 'серьёзно', 'считаться', 'с', 'котами', 'коты', 'и', 'вполне', 'справедливо', 'считают', 'скотами']

# %%
print((words).count("коты"))
# Out:
# 13

# %%
#Есть массив слов из предыдущего стихотворения (с обрезанной пунктуацией)
#Пользователь должен ввести с клавиатуры какое-нибудь слово
#Проверяем, есть ли слово в массиве: если нет, добавляем его туда и печатаем "Слово такое-то добавлено", а если есть, то печатаем ответ "Слово такое-то встречается в тексте столько-то раз"

userword = input("Введите какое-нибудь слово")

if userword not in words:
    words.append(userword)
    print("Слово добавлено")
else:
        print("Слово встречается в тексте %s" % (comparison))
